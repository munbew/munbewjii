# %% [markdown]
# <a href="https://colab.research.google.com/github/munbew/munbewjii/blob/master/Copy_of_FoundedEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Data Collection

# %% [markdown]
# # Importing packages

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # 1. Loading the Raw Data¶

# %%
# Loading the data

movies = pd.read_csv("movies.csv")

#runs the first 5 rows
movies.head()
# Out:
#    color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0  Color      James Cameron  ...          1.78                 33000
# 1  Color     Gore Verbinski  ...          2.35                     0
# 2  Color         Sam Mendes  ...          2.35                 85000
# 3  Color  Christopher Nolan  ...          2.35                164000
# 4  Color     Andrew Stanton  ...          2.35                 24000
#
# [5 rows x 28 columns]

# %% [markdown]
# # 2. Line Graph

# %%
# The line graph is used to answer the question: What does the relationship between the duration and
# budget tell about the genres of movies the fans like to watch?

# Example 1 - Simple 1 line graph
# Investigating the correlation of two variables to the moviegoer's film perferences.

plt.figure(figsize=(20, 20))
ax = sns.lineplot(x='duration', y='budget', data = movies)

# Notes: error bands show the confidence interval

# %%
# Example 2 - Adding Categories

# By Color column

plt.figure(figsize=(20, 20))
ax = sns.lineplot(x='duration', y='budget', hue = 'color', data = movies)

# %% [markdown]
# # 3. lmplots

# %%
# Example 2 - Relationship between movie titles and imdb scores to answer the question:
# How does these variable factors describe moviegoers interest in the genres of films?
sns.set(color_codes=True)
ax = sns.lmplot(x="imdb_score", y="gross (in thousands)", height=15, data=movies)

# %% [markdown]
# # 4. Bar plots

# %%
# Example 4 - Investigating the Return on Investment (ROI) based on the gross revenues and budgeting to come
# with this question: How will the ROI help to choose which genres of movies to produce?

profits = []
roi_vals = []

for index, row in movies.iterrows():
    profit = row['gross (in thousands)']- row['budget']
    budget = row['budget']
    num = profit - budget
    den = budget
    # convert roi to percentage
    roi = (num / den) * 100
    
    profits.append(profit)
    roi_vals.append(roi)
    
movies['profit'] = profits
movies['roi'] = roi_vals

movies.head()
pd.set_option('display.max_rows', None)

print(movies)
# Out:
#                  color  ...            roi
# 0                Color  ...     120.675105
# 1                Color  ...     -97.000000
# 2                Color  ...    -118.367347
# 3                Color  ...     -20.800000
# 4                Color  ...    -172.348485
# 5                Color  ...     -69.561898
# 6                Color  ...    -122.766438
# 7                Color  ...     -16.403360
# 8                Color  ...     -79.217208
# 9                Color  ...     -67.900375
# 10               Color  ...    -104.273011
# 11               Color  ...    -115.815787
# 12               Color  ...     -11.985499
# 13               Color  ...    -158.469809
# 14               Color  ...     -70.657082
# 15               Color  ...    -137.060434
# 16               Color  ...      83.308885
# 17               Color  ...    -103.574450
# 18               Color  ...    -120.435176
# 19               Color  ...     -97.956652
# 20               Color  ...     -86.073625
# ...

# %%
# Example 4 - Investigating the Return on Investment (ROI) based on the gross revenues, budget, and imdb scores to come
# with this question: How will the ROI help in deciding which genres of movies to produce?

profits = []
roi_vals = []

for index, row in movies.iterrows():
    profit = row['gross (in thousands)']- row['budget']
    budget = row['budget']
    num = profit - budget
    den = budget
    # convert roi to percentage
    roi = (num / den) * 100
    
    profits.append(profit)
    roi_vals.append(roi)
    
movies['profit'] = profits
movies['roi'] = roi_vals

movies.head()

plt.figure(figsize=(25,20))

ax = sns.barplot(x='imdb_score', y='roi', data=movies)
