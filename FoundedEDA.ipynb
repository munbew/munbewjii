# %% [markdown]
# # I. Data Collection

# %% [markdown]
# # Importing packages

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 1. Loading the Raw Data¶

# %%
# Loading the data

movies = pd.read_csv("movies.csv")

#runs the first 5 rows
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes  gross (in thousands)  \
# 0                  1000.0                 760.0
# 1                 40000.0                 309.0
# ...

# %% [markdown]
# # 2. Line Graph

# %%
# The line graph is used to answer the question: What does the relationship between the imdb scores and
# movie_facebook_likes tell about the genres of movies the fans like to watch?

# Example 1 - Simple 1 line graph
# Investigating the correlation of two variables to the moviegoer's film perferences.

ax = sns.lineplot(x='movie_facebook_likes', y='imdb_score', data = movies)

# Notes: error bands show the confidence interval

# %%
# Example 2 - Adding Categories

# By Color column
ax = sns.lineplot(x='imdb_score', y='movie_facebook_likes', hue = 'color', data = movies)

# %% [markdown]
# # 3. lmplots

# %%
# Example 2 - Relationship between gross revenues and imdb scores to answer the question:
# How does these variable factors describe moviegoers interest in the genres of films?
sns.set(color_codes=True)
ax = sns.lmplot(x="imdb_score", y="gross (in thousands)", data=movies, palette=dict(Yes="g", No="m"))

# %% [markdown]
# # 4. Bar plots

# %%
# Example 4 - Investigating the Return on Investment (ROI) based on the gross revenues and budgeting to come
# with this question: How will the ROI help to choose which genres of movies to produce?

ax = sns.barplot(x="budget", y="gross (in thousands)", data=movies)

# Notes: 
# 1 - the lines signify the confidence interval
# 2 - Takes mean by default

movies[['budget', 'gross (in thousands)']].groupby('budget', as_index = False).agg({'gross (in thousands)':'mean'})
# Out:
#            budget  gross (in thousands)
# 0    2.180000e+02              592014.0
# 1    2.370000e+02                 760.0
# 2    2.450000e+02                 200.0
# 3    2.500000e+02                 448.0
# 4    2.640000e+02                  73.0
# ..            ...                   ...
# 436  2.127520e+09              410388.0
# 437  2.400000e+09             2298191.0
# 438  2.500000e+09              195888.0
# 439  4.200000e+09              211667.0
# 440  1.221550e+10             2201412.0
#
# [441 rows x 2 columns]
